# %%
import numpy
import pandas as pd
import csv
import matplotlib.pyplot as plt 

# fix random seed for reproducibility
numpy.random.seed(7)
# load pima indians dataset
dataset = pd.read_csv("/content/Alternative Hedge Fund Return (Edited).csv")
# split into input (X) and output (Y) variables

print("Data ===============")
print(dataset)
print("Sum ===============")
print(dataset.sum(1))
# summary statistics
print("Describe ===============")
print(dataset.describe())

corr=df.corr(method ='pearson')
print("Correlation ============")
print(corr)
corr.to_csv('corr.csv')

corr = dataset.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

i=0
while i < dataset.shape[1] :
  plt.plot(dataset.iloc[:,i])
  plt.show()
  i=i+1

boxplot = pd.DataFrame(df).boxplot()
# Out:
# Data ===============
#      Convertible.Arbitrage  CTA.Global  ...  Short.Selling  Funds.Of.Funds
# 0                   0.0119      0.0393  ...        -0.0166          0.0317
# 1                   0.0123      0.0298  ...         0.0426          0.0106
# 2                   0.0078     -0.0021  ...         0.0778         -0.0077
# 3                   0.0086     -0.0170  ...        -0.0129          0.0009
# 4                   0.0156     -0.0015  ...        -0.0737          0.0275
# ..                     ...         ...  ...            ...             ...
# 258                 0.0021     -0.0058  ...        -0.0052          0.0018
# 259                 0.0024      0.0166  ...        -0.0214          0.0015
# 260                 0.0034     -0.0054  ...         0.0036         -0.0022
# 261                -0.0073     -0.0314  ...         0.0237         -0.0269
# 262                -0.0068     -0.0053  ...        -0.0021         -0.0071
#
# [263 rows x 13 columns]
# Sum ===============
# 0      0.3409
# 1      0.2228
# 2      0.0595
# 3      0.0566
# 4      0.1752
#         ...
# 258    0.0206
# 259   -0.0176
# 260    0.0015
# 261   -0.1988
# 262   -0.0673
# Length: 263, dtype: float64
# Describe ===============
#        Convertible.Arbitrage  CTA.Global  ...  Short.Selling  Funds.Of.Funds
# count             263.000000  263.000000  ...     263.000000      263.000000
# mean                0.005508    0.004074  ...      -0.001701        0.004262
# std                 0.016567    0.023335  ...       0.047746        0.015566
# min                -0.123700   -0.056800  ...      -0.134000       -0.061800
# 25%                -0.000150   -0.012050  ...      -0.027100       -0.003500
# 50%                 0.006500    0.001400  ...      -0.005300        0.005200
# 75%                 0.013600    0.019850  ...       0.019850        0.012100
# max                 0.061100    0.069100  ...       0.246300        0.066600
#
# [8 rows x 13 columns]
# Correlation ============
#                         Convertible.Arbitrage  ...  Funds.Of.Funds
# Convertible.Arbitrage                1.000000  ...        0.641654
# CTA.Global                          -0.021677  ...        0.195092
# Distressed.Securities                0.730392  ...        0.815048
# Emerging.Markets                     0.593877  ...        0.849069
# Equity.Market.Neutral                0.498584  ...        0.696463
# Event.Driven                         0.725504  ...        0.884750
# Fixed.Income.Arbitrage               0.778722  ...        0.557240
# Global.Macro                         0.398019  ...        0.783808
# Long.Short.Equity                    0.597134  ...        0.920603
# Merger.Arbitrage                     0.550254  ...        0.714827
# Relative.Value                       0.849583  ...        0.828386
# Short.Selling                       -0.350005  ...       -0.630381
# Funds.Of.Funds                       0.641654  ...        1.000000
#
# [13 rows x 13 columns]
